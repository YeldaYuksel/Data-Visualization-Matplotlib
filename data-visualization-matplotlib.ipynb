# %%
#import pandas as pd
#import seaborn as sns
#import matplotlib.pyplot as plt

#df = sns.load_dataset("titanic")
#df.head()

##Visualization with barplot

#df["sex"].value_counts().plot(kind='bar')
#plt.show()


##Visualization with hist

#plt.hist(df["age"])
#plt.show()


##Visualization with boxplot

#(plt.boxplot(df["fare"]))
#plt.show()

# %% [markdown]
# ***barplot example***

# %% [markdown]
# ![Ekran Resmi 2024-09-01 19.25.24.png](attachment:4007511b-8ef4-4d3a-bb79-fcaef9f29697.png)

# %% [markdown]
# ***hist example***

# %% [markdown]
# ![Ekran Resmi 2024-09-01 19.26.56.png](attachment:bef1b906-64b2-46b4-81eb-229fcd6237c5.png)

# %% [markdown]
# ***boxplot example***

# %% [markdown]
# ![Ekran Resmi 2024-09-01 19.39.26.png](attachment:2f734759-5b9d-4bf8-89df-7d6bba3f0961.png)

# %% [markdown]
# **Plot**

# %%
#x = np.array([1, 8])
#y = np.array([0, 150])
#plt.plot(x, y)
#plt.show()


#x = np.array([1, 8])
#y = np.array([0, 150])
#plt.plot(x, y, 'o')
#plt.show()

# %% [markdown]
# ![Ekran Resmi 2024-09-01 19.59.16.png](attachment:157e07c2-d725-4e86-bcbc-d6bbdb1baf02.png)

# %% [markdown]
# ![Ekran Resmi 2024-09-01 20.00.56.png](attachment:4bfa3b61-9a8b-4d6b-9cff-46af77ca7d65.png)

# %% [markdown]
# **Marker**

# %%
#x = np.array([1, 8])
#y = np.array([0, 150])
#plt.plot(x, y, marker='*')
#plt.show()

# %% [markdown]
# ![Ekran Resmi 2024-09-01 20.01.17.png](attachment:4270e834-f929-49c5-a549-e9899f5cc29a.png)

# %% [markdown]
# **Line**

# %%
#x = np.array([1, 8])
#y = np.array([0, 150])
#plt.plot(x, y, linestyle="dotted")
#plt.show()

# %% [markdown]
# [![Ekran Resmi 2024-09-01 20.04.16.png](attachment:ab32f8ef-a5c3-4b9e-ab15-bff3fe5a2583.png)

# %% [markdown]
# **Multiple Lines**

# %%
#x = np.array([1, 8])
#y = np.array([0, 150])
#plt.plot(x)
#plt.plot(y)
#plt.show()

# %% [markdown]
# ![Ekran Resmi 2024-09-01 20.05.56.png](attachment:a3fcdd23-8d60-4647-8812-09b1805900e5.png)
